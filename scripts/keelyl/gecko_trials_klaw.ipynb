# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
from os.path import join, exists
from matplotlib.colors import LogNorm
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from sklearn.model_selection import GroupKFold
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # General Notes
#
# Bin values should be from -6.5 to 6.5 instead of starting at -5.5
#
# Inputs are everything in summary file + Precursor, Gas, and Aerosol
# StandardScaler

# %% [markdown]
# # Summary file
#
# The summary file contains the metadata for each experiment. Load first in order to know which experiment files to load later.

# %%
summary_file = "/glade/scratch/siyuan/POSTPROCESSING/ML2019_toluene_kOH/Batch1_toluene/GAR0084_Exp_List_TEXT_PreCompile_BatchSubmit_v0.csv"
summary_data = pd.read_csv(summary_file, skiprows=3)
summary_data.columns = summary_data.columns.str.strip()
summary_data.columns
summary_data["idnum"] = summary_data.index

# %%
summary_data
# Out:
#            id  temperature (K)  solar zenith angle (degree)  \
# 0        Exp0            270.0                          0.0
# 1        Exp1            270.0                          0.0
# 2        Exp2            270.0                          0.0
# 3        Exp3            270.0                          0.0
# 4        Exp4            270.0                          0.0
# ...       ...              ...                          ...
# 5395  Exp5395            300.0                         90.0
# 5396  Exp5396            300.0                         90.0
# 5397  Exp5397            300.0                         90.0
# 5398  Exp5398            300.0                         90.0
# 5399  Exp5399            300.0                         90.0
#
#       pre-existing aerosols (ug/m3)  o3 (ppb)  nox (ppb)  oh (10^6 molec/cm3)  \
# 0                              0.01       1.0       0.01                  1.0
# 1                              0.01       1.0       0.01                  5.0
# 2                              0.01       1.0       0.01                 10.0
# 3                              0.01       1.0       0.10                  1.0
# 4                              0.01       1.0       0.10                  5.0
# ...                             ...       ...        ...                  ...
# 5395                         100.00     150.0       3.00                  5.0
# 5396                         100.00     150.0       3.00                 10.0
# 5397                         100.00     150.0      10.00                  1.0
# 5398                         100.00     150.0      10.00                  5.0
# 5399                         100.00     150.0      10.00                 10.0
#
#       idnum
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 5395   5395
# 5396   5396
# 5397   5397
# 5398   5398
# 5399   5399
#
# [5400 rows x 8 columns]

# %%
def load_data(path, summary_file, species="toluene_kOH"):
    """
    Load a set of experiment files based on a summary file.
    
    Args:
        path: Path to the directory containing summary and experiment files
        summary_file: Name of the summary file (should not contain the path)
        species: Name of the precursor chemical species
    
    Returns:
        exp_data_merged: All time series data for every experiment in pandas DataFrame
        summary_data: Summary experiment data file in pandas DataFrame
    """
    summary_data = pd.read_csv(join(path, summary_file), skiprows=3)
    summary_data.columns = summary_data.columns.str.strip()
    summary_data["idnum"] = summary_data.index
    exp_data_list = []
    for i, id_val in enumerate(summary_data["id"]):
        if i % 100 == 0:
            print(id_val)
        exp_file = join(path, f"ML2019_{species}_ML2019_{id_val}.csv")
        exp_data_list.append(pd.read_csv(exp_file))
        exp_data_list[-1]["id"] = id_val
        exp_data_list[-1]["idnum"] = i
        exp_data_list[-1]["timestep"] = np.arange(exp_data_list[-1].shape[0])
    exp_data_combined = pd.concat(exp_data_list, ignore_index=True)
    exp_data_combined.columns = exp_data_combined.columns.str.strip()
    exp_data_merged = pd.merge(exp_data_combined, summary_data, left_on="idnum", right_on="idnum")
    return exp_data_merged, summary_data

# %% [markdown]
# Run the cell below to load all experiment data. It will take a few minutes to run.

# %%
exp_data_merged, summary_data = load_data("/glade/work/dgagne/Batch1_toluene", 
                                          "GAR0084_Exp_List_TEXT_PreCompile_BatchSubmit_v0.csv")
# Out:
# Exp0
# Exp100
# Exp200
# Exp300
# Exp400
# Exp500
# Exp600
# Exp700
# Exp800
# Exp900
# Exp1000
# Exp1100
# Exp1200
# Exp1300
# Exp1400
# Exp1500
# Exp1600
# Exp1700
# Exp1800
# Exp1900
# Exp2000
# Exp2100
# Exp2200
# Exp2300
# Exp2400
# Exp2500
# Exp2600
# Exp2700
# Exp2800
# Exp2900
# Exp3000
# Exp3100
# Exp3200
# Exp3300
# Exp3400
# Exp3500
# Exp3600
# Exp3700
# Exp3800
# Exp3900
# Exp4000
# Exp4100
# Exp4200
# Exp4300
# Exp4400
# Exp4500
# Exp4600
# Exp4700
# Exp4800
# Exp4900
# Exp5000
# Exp5100
# Exp5200
# Exp5300

# %% [markdown]
# Here is a summary of what the data look like for a single experiment.

# %%
exp_data_merged.loc[exp_data_merged["idnum"] == 10]
# Out:
#            Time [s]  Precursor [ug/m3]  Gas [ug/m3] Bin01: lg(C*) = -5.5  \
# 5760       1.000000           0.037689                      0.000000e+00
# 5761     301.519989           0.037332                      1.113952e-21
# 5762     602.039978           0.036979                      8.465895e-21
# 5763     902.559998           0.036628                      3.248028e-20
# 5764    1203.079956           0.036281                      1.030769e-19
# ...             ...                ...                               ...
# 6331  171597.921875           0.000165                      1.043278e-13
# 6332  171898.437500           0.000163                      1.041344e-13
# 6333  172198.953125           0.000162                      1.039410e-13
# 6334  172499.484375           0.000160                      1.037479e-13
# 6335  172800.000000           0.000159                      1.035551e-13
#
#       Gas [ug/m3] Bin02: lg(C*) = -4.5  Gas [ug/m3] Bin03: lg(C*) = -3.5  \
# 5760                      0.000000e+00                      0.000000e+00
# 5761                      4.070264e-20                      6.686731e-17
# 5762                      2.655437e-19                      1.143732e-16
# 5763                      7.934065e-19                      2.488888e-15
# 5764                      2.069284e-18                      3.476972e-15
# ...                                ...                               ...
# 6331                      1.525949e-12                      1.460513e-10
# 6332                      1.523302e-12                      1.458010e-10
# 6333                      1.520657e-12                      1.455456e-10
# 6334                      1.518013e-12                      1.452935e-10
# 6335                      1.515372e-12                      1.450410e-10
#
#       Gas [ug/m3] Bin04: lg(C*) = -2.5  Gas [ug/m3] Bin05: lg(C*) = -1.5  \
# 5760                      0.000000e+00                      0.000000e+00
# 5761                      1.389201e-16                      4.066288e-15
# 5762                      1.790802e-15                      2.412341e-14
# 5763                      9.371479e-15                      1.919735e-13
# 5764                      2.874213e-14                      4.096286e-13
# ...                                ...                               ...
# 6331                      1.237334e-09                      3.408873e-08
# 6332                      1.234989e-09                      3.408640e-08
# 6333                      1.232646e-09                      3.408390e-08
# 6334                      1.230307e-09                      3.408143e-08
# 6335                      1.227971e-09                      3.407893e-08
#
#       Gas [ug/m3] Bin06: lg(C*) = -0.5  Gas [ug/m3] Bin07: lg(C*) =  0.5  \
# 5760                      0.000000e+00                      0.000000e+00
# 5761                      1.757855e-13                      9.118843e-12
# 5762                      4.494002e-12                      6.651374e-11
# 5763                      2.865727e-11                      2.018920e-10
# 5764                      1.022437e-10                      4.320647e-10
# ...                                ...                               ...
# 6331                      1.015127e-06                      4.097190e-07
# 6332                      1.008500e-06                      4.094157e-07
# 6333                      1.001909e-06                      4.091112e-07
# 6334                      9.953547e-07                      4.088050e-07
# 6335                      9.888363e-07                      4.084956e-07
#
#       Gas [ug/m3] Bin08: lg(C*) =  1.5  ...   id_x  idnum  timestep   id_y  \
# 5760                      0.000000e+00  ...  Exp10     10         0  Exp10
# 5761                      5.212791e-12  ...  Exp10     10         1  Exp10
# 5762                      3.789099e-11  ...  Exp10     10         2  Exp10
# 5763                      1.266861e-10  ...  Exp10     10         3  Exp10
# 5764                      2.948841e-10  ...  Exp10     10         4  Exp10
# ...                                ...  ...    ...    ...       ...    ...
# 6331                      9.564674e-09  ...  Exp10     10       571  Exp10
# 6332                      9.512465e-09  ...  Exp10     10       572  Exp10
# 6333                      9.417578e-09  ...  Exp10     10       573  Exp10
# 6334                      9.325147e-09  ...  Exp10     10       574  Exp10
# 6335                      9.232842e-09  ...  Exp10     10       575  Exp10
#
#       temperature (K)  solar zenith angle (degree)  \
# 5760            270.0                          0.0
# 5761            270.0                          0.0
# 5762            270.0                          0.0
# 5763            270.0                          0.0
# 5764            270.0                          0.0
# ...               ...                          ...
# 6331            270.0                          0.0
# 6332            270.0                          0.0
# 6333            270.0                          0.0
# 6334            270.0                          0.0
# 6335            270.0                          0.0
#
#       pre-existing aerosols (ug/m3)  o3 (ppb)  nox (ppb)  oh (10^6 molec/cm3)
# 5760                           0.01       1.0        1.0                  5.0
# 5761                           0.01       1.0        1.0                  5.0
# 5762                           0.01       1.0        1.0                  5.0
# 5763                           0.01       1.0        1.0                  5.0
# 5764                           0.01       1.0        1.0                  5.0
# ...                             ...       ...        ...                  ...
# 6331                           0.01       1.0        1.0                  5.0
# 6332                           0.01       1.0        1.0                  5.0
# 6333                           0.01       1.0        1.0                  5.0
# 6334                           0.01       1.0        1.0                  5.0
# 6335                           0.01       1.0        1.0                  5.0
#
# [576 rows x 138 columns]

# %% [markdown]
# Here are the relevant input and output columns for training the neural network. We are going to start with a subset of the data and then add more variables over time if we get good performance with these.

# %%
input_exp_cols = ['Precursor [ug/m3]',
    'Gas [ug/m3] Bin01: lg(C*) = -5.5',
    'Gas [ug/m3] Bin02: lg(C*) = -4.5',
    'Gas [ug/m3] Bin03: lg(C*) = -3.5',
    'Gas [ug/m3] Bin04: lg(C*) = -2.5',
    'Gas [ug/m3] Bin05: lg(C*) = -1.5',
    'Gas [ug/m3] Bin06: lg(C*) = -0.5',
    'Gas [ug/m3] Bin07: lg(C*) =  0.5',
    'Gas [ug/m3] Bin08: lg(C*) =  1.5',
    'Gas [ug/m3] Bin09: lg(C*) =  2.5',
    'Gas [ug/m3] Bin10: lg(C*) =  3.5',
    'Gas [ug/m3] Bin11: lg(C*) =  4.5',
    'Gas [ug/m3] Bin12: lg(C*) =  5.5',
    'Gas [ug/m3] Bin13: lg(C*) =  6.5',
    'Gas [ug/m3] Bin14: lg(C*) = -6.5',
    'Aerosol [ug_m3] Bin01: lg(C*) = -5.5',
    'Aerosol [ug_m3] Bin02: lg(C*) = -4.5',
    'Aerosol [ug_m3] Bin03: lg(C*) = -3.5',
    'Aerosol [ug_m3] Bin04: lg(C*) = -2.5',
    'Aerosol [ug_m3] Bin05: lg(C*) = -1.5',
    'Aerosol [ug_m3] Bin06: lg(C*) = -0.5',
    'Aerosol [ug_m3] Bin07: lg(C*) =  0.5',
    'Aerosol [ug_m3] Bin08: lg(C*) =  1.5',
    'Aerosol [ug_m3] Bin09: lg(C*) =  2.5',
    'Aerosol [ug_m3] Bin10: lg(C*) =  3.5',
    'Aerosol [ug_m3] Bin11: lg(C*) =  4.5',
    'Aerosol [ug_m3] Bin12: lg(C*) =  5.5',
    'Aerosol [ug_m3] Bin13: lg(C*) =  6.5',
    'Aerosol [ug_m3] Bin14: lg(C*) = -6.5',
    'temperature (K)',
    'solar zenith angle (degree)',
    'pre-existing aerosols (ug/m3)',
    'o3 (ppb)',
    'nox (ppb)',
    'oh (10^6 molec/cm3)',
    "idnum"]

output_exp_cols = ['Precursor [ug/m3]',
    'Gas [ug/m3] Bin01: lg(C*) = -5.5',
    'Gas [ug/m3] Bin02: lg(C*) = -4.5',
    'Gas [ug/m3] Bin03: lg(C*) = -3.5',
    'Gas [ug/m3] Bin04: lg(C*) = -2.5',
    'Gas [ug/m3] Bin05: lg(C*) = -1.5',
    'Gas [ug/m3] Bin06: lg(C*) = -0.5',
    'Gas [ug/m3] Bin07: lg(C*) =  0.5',
    'Gas [ug/m3] Bin08: lg(C*) =  1.5',
    'Gas [ug/m3] Bin09: lg(C*) =  2.5',
    'Gas [ug/m3] Bin10: lg(C*) =  3.5',
    'Gas [ug/m3] Bin11: lg(C*) =  4.5',
    'Gas [ug/m3] Bin12: lg(C*) =  5.5',
    'Gas [ug/m3] Bin13: lg(C*) =  6.5',
    'Gas [ug/m3] Bin14: lg(C*) = -6.5',
    'Aerosol [ug_m3] Bin01: lg(C*) = -5.5',
    'Aerosol [ug_m3] Bin02: lg(C*) = -4.5',
    'Aerosol [ug_m3] Bin03: lg(C*) = -3.5',
    'Aerosol [ug_m3] Bin04: lg(C*) = -2.5',
    'Aerosol [ug_m3] Bin05: lg(C*) = -1.5',
    'Aerosol [ug_m3] Bin06: lg(C*) = -0.5',
    'Aerosol [ug_m3] Bin07: lg(C*) =  0.5',
    'Aerosol [ug_m3] Bin08: lg(C*) =  1.5',
    'Aerosol [ug_m3] Bin09: lg(C*) =  2.5',
    'Aerosol [ug_m3] Bin10: lg(C*) =  3.5',
    'Aerosol [ug_m3] Bin11: lg(C*) =  4.5',
    'Aerosol [ug_m3] Bin12: lg(C*) =  5.5',
    'Aerosol [ug_m3] Bin13: lg(C*) =  6.5',
    'Aerosol [ug_m3] Bin14: lg(C*) = -6.5',
    "idnum", 'timestep']

# %%
output_exp_cols
# Out:
# ['Precursor [ug/m3]',
#  'Gas [ug/m3] Bin01: lg(C*) = -5.5',
#  'Gas [ug/m3] Bin02: lg(C*) = -4.5',
#  'Gas [ug/m3] Bin03: lg(C*) = -3.5',
#  'Gas [ug/m3] Bin04: lg(C*) = -2.5',
#  'Gas [ug/m3] Bin05: lg(C*) = -1.5',
#  'Gas [ug/m3] Bin06: lg(C*) = -0.5',
#  'Gas [ug/m3] Bin07: lg(C*) =  0.5',
#  'Gas [ug/m3] Bin08: lg(C*) =  1.5',
#  'Gas [ug/m3] Bin09: lg(C*) =  2.5',
#  'Gas [ug/m3] Bin10: lg(C*) =  3.5',
#  'Gas [ug/m3] Bin11: lg(C*) =  4.5',
#  'Gas [ug/m3] Bin12: lg(C*) =  5.5',
#  'Gas [ug/m3] Bin13: lg(C*) =  6.5',
#  'Gas [ug/m3] Bin14: lg(C*) = -6.5',
#  'Aerosol [ug_m3] Bin01: lg(C*) = -5.5',
#  'Aerosol [ug_m3] Bin02: lg(C*) = -4.5',
#  'Aerosol [ug_m3] Bin03: lg(C*) = -3.5',
#  'Aerosol [ug_m3] Bin04: lg(C*) = -2.5',
#  'Aerosol [ug_m3] Bin05: lg(C*) = -1.5',
#  'Aerosol [ug_m3] Bin06: lg(C*) = -0.5',
#  'Aerosol [ug_m3] Bin07: lg(C*) =  0.5',
#  'Aerosol [ug_m3] Bin08: lg(C*) =  1.5',
#  'Aerosol [ug_m3] Bin09: lg(C*) =  2.5',
#  'Aerosol [ug_m3] Bin10: lg(C*) =  3.5',
#  'Aerosol [ug_m3] Bin11: lg(C*) =  4.5',
#  'Aerosol [ug_m3] Bin12: lg(C*) =  5.5',
#  'Aerosol [ug_m3] Bin13: lg(C*) =  6.5',
#  'Aerosol [ug_m3] Bin14: lg(C*) = -6.5',
#  'idnum',
#  'timestep']

# %%
#    ~~Calculating Past Trials~~

# %%
# import
trial_num = "34"
    
prediction_file = "/glade/work/keelyl/trial_%s.csv" % trial_num
prediction_data = pd.read_csv(prediction_file)

# %%
# Aerosol Final Mass RMSE
sel_col8 = output_data.columns.str.contains("Aerosol")
sel_col9= prediction_data.columns.str.contains("Aerosol")
aer_output_dat_final= output_data.values[:, sel_col8]
aer_out_pred_final= prediction_data.values[:, sel_col9]
print(aer_output_dat_final.shape)
aer_final_mass_data = np.sum(aer_output_dat_final, axis=1)
aer_final_mass_pred = np.sum(aer_out_pred_final, axis=1)

aerosol_mass_RMSE = np.sqrt(np.square(np.subtract(aer_final_mass_data,aer_final_mass_pred)).mean())
print(aerosol_mass_RMSE)
# Out:
# (3105000, 14)
# 6.8779447946630535e-06

# %%
aer_final_mass_data.mean()
# Out:
# 0.0014292121213746853

# %%
# Gas Final Mass RMSE
sel_col10 = output_data.columns.str.contains("Gas")
sel_col11= prediction_data.columns.str.contains("Gas")
gas_output_dat_final= output_data.values[:, sel_col10]
gas_out_pred_final= prediction_data.values[:, sel_col11]
print(gas_output_dat_final.shape)
gas_final_mass_data = np.sum(gas_output_dat_final, axis=1)
gas_final_mass_pred = np.sum(gas_out_pred_final, axis=1)

gas_mass_RMSE = np.sqrt(np.square(np.subtract(gas_final_mass_data,gas_final_mass_pred)).mean())
print(gas_mass_RMSE)
# Out:
# (3105000, 14)
# 2.21265729103637e-05

# %%
gas_final_mass_data.mean()
# Out:
# 0.013456140523955537

# %%
# Precursor Final Mass RMSE

sel_col12 = output_data.columns.str.contains("Precursor")
sel_col13= prediction_data.columns.str.contains("Precursor")
pre_output_dat_final= output_data.values[:, sel_col12]
pre_out_pred_final= prediction_data.values[:, sel_col13]
print(pre_output_dat_final.shape)
pre_final_mass_data = np.sum(pre_output_dat_final, axis=1)
pre_final_mass_pred = np.sum(pre_out_pred_final, axis=1)

pre_mass_RMSE = np.sqrt(np.square(np.subtract(pre_output_dat_final,pre_out_pred_final)).mean())
print(pre_mass_RMSE)
# Out:
# (3105000, 1)
# 2.9977826660252923e-05

# %%
pre_final_mass_data.mean()
# Out:
# 0.011448578200765043

# %%
trial = "39"
#Aerosol [ug_m3] Bin08
col = output_data.columns[output_data.columns.str.contains("Aerosol")][7]
plt.figure(figsize=(5, 5))
plt.plot(output_data.loc[:574, col], color='blue', label="GECKO-A")
plt.plot(prediction_data.loc[:574, col], color="green", label="Dense ANN Emulator")
plt.title("Aerosol [ug_m3] Bin08", fontsize=18)
plt.ylabel("Aerosol Concentration", fontsize=14)
plt.xlabel("Time Step", fontsize=14)
plt.legend(fontsize=14)
plt.savefig("plot3_Bin08_trial_%s.png" % trial, dpi=200, bbox_inches="tight")

#Aerosol [ug_m3] Bin07
col1 = output_data.columns[output_data.columns.str.contains("Aerosol")][6]
plt.figure(figsize=(5, 5))
plt.plot(output_data.loc[:574, col1], color='blue', label="GECKO-A")
plt.plot(prediction_data.loc[:574, col1], color="orange", label="Dense ANN Emulator")
plt.title("Aerosol [ug_m3] Bin07", fontsize=18)
plt.ylabel("Aerosol [ug_m3] Bin07", fontsize=14)
plt.xlabel("Time Step", fontsize=14)
plt.legend(fontsize=14)
plt.savefig("plot3_Bin07_trial_%s.png" % trial, dpi=200, bbox_inches="tight")

#Aerosol [ug_m3] Bin06
col2 = output_data.columns[output_data.columns.str.contains("Aerosol")][5]
plt.figure(figsize=(5, 5))
plt.plot(output_data.loc[:574, col2], color='blue', label="GECKO-A")
plt.plot(prediction_data.loc[:574, col2], color="purple", label="Dense ANN Emulator")
plt.title("Aerosol [ug_m3] Bin06", fontsize=18)
plt.ylabel("Aerosol Concentration", fontsize=14)
plt.xlabel("Time Step", fontsize=14)
plt.legend(fontsize=14)
plt.savefig("plot3_Bin06_trial_%s.png" % trial, dpi=200, bbox_inches="tight")

# %%
# ~~ calculations end ~~

# %%
input_data_list = []
output_data_list = []
for exp in np.unique(exp_data_merged.idnum):
    if exp % 100 == 0:
        print(exp)
    input_data_list.append(exp_data_merged.loc[exp_data_merged.idnum==exp, input_exp_cols].reset_index(drop=True).iloc[:-1])
    output_data_list.append(exp_data_merged.loc[exp_data_merged.idnum==exp, input_exp_cols].reset_index(drop=True).iloc[1:])
input_data = pd.concat(input_data_list, ignore_index=True)
output_data = pd.concat(output_data_list, ignore_index=True)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300

# %%
def dense_neural_net(num_layers, num_neurons, activation, learning_rate, input_train_norm, output_train_norm):
    input_layer = Input(input_train_norm.shape[1])
    n_net = input_layer
    for l in range(num_layers):
        n_net= Dense(num_neurons, activation=activation)(n_net)
    out = Dense(output_train_norm.shape[1])(n_net)
    mod = Model(input_layer, out)
    mod.compile(Adam(learning_rate=learning_rate), "mse")
    return mod

# %%
output_data
# Out:
#          Precursor [ug/m3]  Gas [ug/m3] Bin01: lg(C*) = -5.5  \
# 0                 0.037617                      8.155637e-22
# 1                 0.037546                      3.133494e-20
# 2                 0.037474                      7.587363e-19
# 3                 0.037403                      6.855157e-18
# 4                 0.037332                      3.443392e-17
# ...                    ...                               ...
# 3104995           0.000003                      1.311393e-20
# 3104996           0.000003                      1.285304e-20
# 3104997           0.000002                      1.261603e-20
# 3104998           0.000002                      1.236282e-20
# 3104999           0.000002                      1.212451e-20
#
#          Gas [ug/m3] Bin02: lg(C*) = -4.5  Gas [ug/m3] Bin03: lg(C*) = -3.5  \
# 0                            1.263573e-21                      9.544929e-15
# 1                            2.270322e-20                      8.156982e-14
# 2                            2.431687e-19                      1.762050e-13
# 3                            1.987312e-18                      4.766778e-13
# 4                            1.003384e-17                      1.250521e-12
# ...                                   ...                               ...
# 3104995                      2.077611e-19                      1.280348e-15
# 3104996                      2.040848e-19                      1.236718e-15
# 3104997                      2.007593e-19                      1.209243e-15
# 3104998                      1.971223e-19                      1.181575e-15
# 3104999                      1.935127e-19                      1.155179e-15
#
#          Gas [ug/m3] Bin04: lg(C*) = -2.5  Gas [ug/m3] Bin05: lg(C*) = -1.5  \
# 0                            3.442271e-15                      4.575265e-14
# 1                            3.495141e-14                      1.502196e-13
# 2                            1.613213e-13                      3.800421e-13
# 3                            6.004466e-13                      9.435875e-13
# 4                            1.829096e-12                      2.037699e-12
# ...                                   ...                               ...
# 3104995                      1.538136e-12                      2.586186e-11
# 3104996                      1.505193e-12                      2.485606e-11
# 3104997                      1.472984e-12                      2.447515e-11
# 3104998                      1.441464e-12                      2.411553e-11
# 3104999                      1.410658e-12                      2.429800e-11
#
#          Gas [ug/m3] Bin06: lg(C*) = -0.5  Gas [ug/m3] Bin07: lg(C*) =  0.5  \
# 0                            4.100273e-14                      6.194109e-12
# 1                            9.871184e-14                      1.530814e-10
# 2                            5.421686e-13                      7.975155e-10
# 3                            1.677539e-12                      2.326122e-09
# 4                            3.966482e-12                      5.063882e-09
# ...                                   ...                               ...
# 3104995                      5.037383e-10                      9.675625e-10
# 3104996                      4.948298e-10                      9.546565e-10
# 3104997                      4.860567e-10                      9.388274e-10
# 3104998                      4.774176e-10                      9.244614e-10
# 3104999                      4.689177e-10                      9.089280e-10
#
#          Gas [ug/m3] Bin08: lg(C*) =  1.5  Gas [ug/m3] Bin09: lg(C*) =  2.5  \
# 0                            4.735757e-13                      3.587263e-13
# 1                            1.336650e-11                      6.554171e-12
# 2                            7.596344e-11                      4.056534e-11
# 3                            2.405779e-10                      1.320380e-10
# 4                            5.614299e-10                      3.121042e-10
# ...                                   ...                               ...
# 3104995                      3.249457e-09                      1.233069e-05
# 3104996                      3.200388e-09                      1.216130e-05
# 3104997                      3.151121e-09                      1.199395e-05
# 3104998                      3.102326e-09                      1.182844e-05
# 3104999                      3.054784e-09                      1.166500e-05
#
#          ...  Aerosol [ug_m3] Bin12: lg(C*) =  5.5  \
# 0        ...                          3.006734e-14
# 1        ...                          6.695180e-13
# 2        ...                          3.572964e-12
# 3        ...                          1.104469e-11
# 4        ...                          2.566590e-11
# ...      ...                                   ...
# 3104995  ...                          1.290958e-05
# 3104996  ...                          1.301735e-05
# 3104997  ...                          1.312596e-05
# 3104998  ...                          1.323535e-05
# 3104999  ...                          1.334545e-05
#
#          Aerosol [ug_m3] Bin13: lg(C*) =  6.5  \
# 0                                3.498849e-13
# 1                                1.730959e-12
# 2                                4.297890e-12
# 3                                8.062719e-12
# 4                                1.300682e-11
# ...                                       ...
# 3104995                          1.407636e-06
# 3104996                          1.417636e-06
# 3104997                          1.427726e-06
# 3104998                          1.437904e-06
# 3104999                          1.448203e-06
#
#          Aerosol [ug_m3] Bin14: lg(C*) = -6.5  temperature (K)  \
# 0                                1.611725e-11            270.0
# 1                                1.901978e-11            270.0
# 2                                2.214155e-11            270.0
# 3                                2.534768e-11            270.0
# 4                                2.863879e-11            270.0
# ...                                       ...              ...
# 3104995                          3.499209e-07            300.0
# 3104996                          3.505694e-07            300.0
# 3104997                          3.512362e-07            300.0
# 3104998                          3.519205e-07            300.0
# 3104999                          3.526180e-07            300.0
#
#          solar zenith angle (degree)  pre-existing aerosols (ug/m3)  o3 (ppb)  \
# 0                                0.0                           0.01       1.0
# 1                                0.0                           0.01       1.0
# 2                                0.0                           0.01       1.0
# 3                                0.0                           0.01       1.0
# 4                                0.0                           0.01       1.0
# ...                              ...                            ...       ...
# 3104995                         90.0                         100.00     150.0
# 3104996                         90.0                         100.00     150.0
# 3104997                         90.0                         100.00     150.0
# 3104998                         90.0                         100.00     150.0
# 3104999                         90.0                         100.00     150.0
#
#          nox (ppb)  oh (10^6 molec/cm3)  idnum
# 0             0.01                  1.0      0
# 1             0.01                  1.0      0
# 2             0.01                  1.0      0
# 3             0.01                  1.0      0
# 4             0.01                  1.0      0
# ...            ...                  ...    ...
# 3104995      10.00                 10.0   5399
# 3104996      10.00                 10.0   5399
# 3104997      10.00                 10.0   5399
# 3104998      10.00                 10.0   5399
# 3104999      10.00                 10.0   5399
#
# [3105000 rows x 36 columns]

# %%
# ~~ Training ~~

# %% [markdown]
# * Number of folds: 5
# * `num_layers`: Vary from 1 to 5
# * `num_neurons`: Vary from 20 to 200 in steps of 20
# * `activation`: Try "relu", "tanh", "selu"
# * `learning_rate`: 0.01 to 0.00001 dividing by 10
# * `epochs`: Try 10, 20, 50
# * `batch_size`: 256, 512, 1024, 2048
#
# Pick a subset of these options and manually retrain the neural network a few times.

# %%
# change trial number
trial = "26"
num_folds = 5
exp_kfold = GroupKFold(num_folds)
neural_nets = []
num_layers = 1
num_neurons = 100
activation = "relu"
learning_rate = 0.0001
epochs = 50
batch_size = 256
dnns = []
norm_rmse_folds = np.zeros((num_folds, len(output_exp_cols[:-1])))
norm_mae_folds = np.zeros((num_folds, len(output_exp_cols[:-1])))
norm_me_folds = np.zeros((num_folds, len(output_exp_cols[:-1])))
out_preds = np.zeros((output_data.shape[0], len(output_exp_cols)-1), dtype=np.float32)
print(out_preds.shape)
f = 0
for train_index, val_index in exp_kfold.split(input_data, output_data, input_data["idnum"].values):
    normalizer_input = StandardScaler()
    normalizer_output = StandardScaler()
    input_train_norm = normalizer_input.fit_transform(input_data.loc[train_index, input_exp_cols[:-1]])
    input_val_norm = normalizer_input.transform(input_data.loc[val_index, input_exp_cols[:-1]])
    output_train_norm = normalizer_output.fit_transform(output_data.loc[train_index, output_exp_cols[:-1]])
    output_val_norm = normalizer_output.transform(output_data.loc[val_index, output_exp_cols[:-1]])
    dnn = dense_neural_net(num_layers, num_neurons, activation, learning_rate, input_train_norm, output_train_norm)
    dnn.fit(input_train_norm, output_train_norm, batch_size=batch_size, epochs=epochs)
    output_preds_norm = dnn.predict(input_val_norm, batch_size=10000)
    norm_rmse_folds[f] = np.sqrt(np.mean((output_preds_norm - output_val_norm) ** 2, axis=0))
    norm_mae_folds[f] = np.mean(np.abs(output_preds_norm - output_val_norm), axis=0)
    norm_me_folds[f] = np.mean((output_preds_norm - output_val_norm), axis=0)
    out_preds[val_index] = normalizer_output.inverse_transform(output_preds_norm)
    dnns.append(dnn)
    f += 1
out_preds_df = pd.DataFrame(out_preds, index=output_data.index, columns=output_exp_cols[:-1])

# save preds to csv
out_preds_df.to_csv('/glade/work/keelyl/trial_%s.csv' % trial)


# calculate MSE
#sel_col1 = output_data.columns.str.contains("Aerosol", "Gas")
#sel_col2= out_preds_df.columns.str.contains("Aerosol", "Gas")
#out_pred= out_preds_df.values[:, sel_col2]
#output_dat= output_data.values[:, sel_col1]
#MSE = np.square(np.subtract(output_dat,out_pred)).mean()
#print(MSE)
# Out:
# (3105000, 30)
# Train on 2484000 samples
# Epoch 1/50
# 2484000/2484000 [==============================] - 20s 8us/sample - loss: 0.0646
# Epoch 2/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 9.5565e-04
# Epoch 3/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 2.5370e-04
# Epoch 4/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 1.1397e-04
# Epoch 5/50
# 2484000/2484000 [==============================] - 16s 7us/sample - loss: 7.5994e-05
# Epoch 6/50
# 2484000/2484000 [==============================] - 16s 6us/sample - loss: 5.9211e-05
# Epoch 7/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 4.9415e-05
# Epoch 8/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 4.3025e-05
# Epoch 9/50
# 2484000/2484000 [==============================] - 18s 7us/sample - loss: 3.7554e-05
# Epoch 10/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 3.3310e-05
# Epoch 11/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 3.0756e-05
# Epoch 12/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 2.8742e-05
# Epoch 13/50
# 2484000/2484000 [==============================] - 16s 6us/sample - loss: 2.6878e-05
# Epoch 14/50
# 2484000/2484000 [==============================] - 16s 7us/sample - loss: 2.5164e-05
# Epoch 15/50
# 2484000/2484000 [==============================] - 16s 7us/sample - loss: 2.3617e-05
# Epoch 16/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 2.2344e-05
# Epoch 17/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 2.1377e-05
# Epoch 18/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 2.0677e-05
# Epoch 19/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 2.0098e-05
# Epoch 20/50
# 2484000/2484000 [==============================] - 16s 7us/sample - loss: 1.9676e-05
# Epoch 21/50
# 2484000/2484000 [==============================] - 16s 6us/sample - loss: 1.9290e-05
# Epoch 22/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 1.8958e-05
# Epoch 23/50
# 2484000/2484000 [==============================] - 16s 7us/sample - loss: 1.8711e-05
# Epoch 24/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 1.8491e-05
# Epoch 25/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 1.8314e-05
# Epoch 26/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 1.8130e-05
# Epoch 27/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 1.8002e-05
# Epoch 28/50
# 2484000/2484000 [==============================] - 16s 6us/sample - loss: 1.7863e-05
# Epoch 29/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 1.7733e-05
# Epoch 30/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 1.7613e-05
# Epoch 31/50
# 2484000/2484000 [==============================] - 16s 6us/sample - loss: 1.7493e-05
# Epoch 32/50
# 2484000/2484000 [==============================] - 16s 6us/sample - loss: 1.7410e-05
# Epoch 33/50
# 2484000/2484000 [==============================] - 16s 6us/sample - loss: 1.7264e-05
# Epoch 34/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 1.7195e-05
# Epoch 35/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 1.7112e-05
# Epoch 36/50
# 2484000/2484000 [==============================] - 16s 7us/sample - loss: 1.7032e-05
# Epoch 37/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 1.6974e-05
# Epoch 38/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 1.6882e-05
# Epoch 39/50
# 2484000/2484000 [==============================] - 16s 6us/sample - loss: 1.6804e-05
# Epoch 40/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 1.6745e-05
# Epoch 41/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 1.6704e-05
# Epoch 42/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 1.6624e-05
# Epoch 43/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 1.6569e-05
# Epoch 44/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 1.6510e-05
# Epoch 45/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 1.6447e-05
# Epoch 46/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 1.6388e-05
# Epoch 47/50
# 2484000/2484000 [==============================] - 16s 6us/sample - loss: 1.6337e-05
# Epoch 48/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 1.6276e-05
# Epoch 49/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 1.6228e-05
# Epoch 50/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 1.6158e-05
# Train on 2484000 samples
# Epoch 1/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 0.0627
# Epoch 2/50
# 2484000/2484000 [==============================] - 16s 7us/sample - loss: 8.5930e-04
# Epoch 3/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 2.1067e-04
# Epoch 4/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 9.5846e-05
# Epoch 5/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 6.4789e-05
# Epoch 6/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 5.1616e-05
# Epoch 7/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 4.3883e-05
# Epoch 8/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 3.9494e-05
# Epoch 9/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 3.5979e-05
# Epoch 10/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 3.3034e-05
# Epoch 11/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 3.0680e-05
# Epoch 12/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 2.8927e-05
# Epoch 13/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 2.7633e-05
# Epoch 14/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 2.6614e-05
# Epoch 15/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 2.5851e-05
# Epoch 16/50
# 2484000/2484000 [==============================] - 16s 7us/sample - loss: 2.5284e-05
# Epoch 17/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 2.4787e-05
# Epoch 18/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 2.4349e-05
# Epoch 19/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 2.3899e-05
# Epoch 20/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 2.3445e-05
# Epoch 21/50
# 2484000/2484000 [==============================] - 17s 7us/sample - loss: 2.3044e-05
# Epoch 22/50
# 2484000/2484000 [==============================] - 16s 7us/sample - loss: 2.2623e-05
# Epoch 23/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 2.2202e-05
# Epoch 24/50
# 2484000/2484000 [==============================] - 16s 6us/sample - loss: 2.1863e-05
# Epoch 25/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 2.1505e-05
# Epoch 26/50
# 2484000/2484000 [==============================] - 15s 6us/sample - loss: 2.1201e-05
# Epoch 27/50
#   98816/2484000 [>.............................] - ETA: 14s - loss: 2.0903e-05

# %%
# ~~ More Calculations ~~

# %%
plt.hist(aer_final_mass_data - aer_final_mass_pred, bins=30)
plt.gca().set_yscale("log")

# %%
plt.pcolormesh(norm_rmse_folds)
plt.colorbar()
plt.xlabel("Output column")
plt.ylabel("Fold")
plt.savefig("plot1_trial_%s.png" % trial, bbox_inches="tight",dpi=200)

# %% [markdown]
# Average the metrics across folds to get a summary value for all predictions.

# %%
plt.barh(np.arange(29), norm_me_folds.mean(axis=0))
plt.xlabel("Mean Error")
plt.ylabel("Output Column")
plt.savefig("plot2_trial_%s.png" % trial, bbox_inches="tight", dpi=200)

# %%
output_exp_cols
# Out:
# ['Precursor [ug/m3]',
#  'Gas [ug/m3] Bin01: lg(C*) = -5.5',
#  'Gas [ug/m3] Bin02: lg(C*) = -4.5',
#  'Gas [ug/m3] Bin03: lg(C*) = -3.5',
#  'Gas [ug/m3] Bin04: lg(C*) = -2.5',
#  'Gas [ug/m3] Bin05: lg(C*) = -1.5',
#  'Gas [ug/m3] Bin06: lg(C*) = -0.5',
#  'Gas [ug/m3] Bin07: lg(C*) =  0.5',
#  'Gas [ug/m3] Bin08: lg(C*) =  1.5',
#  'Gas [ug/m3] Bin09: lg(C*) =  2.5',
#  'Gas [ug/m3] Bin10: lg(C*) =  3.5',
#  'Gas [ug/m3] Bin11: lg(C*) =  4.5',
#  'Gas [ug/m3] Bin12: lg(C*) =  5.5',
#  'Gas [ug/m3] Bin13: lg(C*) =  6.5',
#  'Gas [ug/m3] Bin14: lg(C*) = -6.5',
#  'Aerosol [ug_m3] Bin01: lg(C*) = -5.5',
#  'Aerosol [ug_m3] Bin02: lg(C*) = -4.5',
#  'Aerosol [ug_m3] Bin03: lg(C*) = -3.5',
#  'Aerosol [ug_m3] Bin04: lg(C*) = -2.5',
#  'Aerosol [ug_m3] Bin05: lg(C*) = -1.5',
#  'Aerosol [ug_m3] Bin06: lg(C*) = -0.5',
#  'Aerosol [ug_m3] Bin07: lg(C*) =  0.5',
#  'Aerosol [ug_m3] Bin08: lg(C*) =  1.5',
#  'Aerosol [ug_m3] Bin09: lg(C*) =  2.5',
#  'Aerosol [ug_m3] Bin10: lg(C*) =  3.5',
#  'Aerosol [ug_m3] Bin11: lg(C*) =  4.5',
#  'Aerosol [ug_m3] Bin12: lg(C*) =  5.5',
#  'Aerosol [ug_m3] Bin13: lg(C*) =  6.5',
#  'Aerosol [ug_m3] Bin14: lg(C*) = -6.5',
#  'idnum']

# %%
#Aerosol [ug_m3] Bin08
col = output_data.columns[output_data.columns.str.contains("Aerosol")][7]
plt.figure(figsize=(5, 5))
plt.plot(output_data.loc[:574, col], color='blue', label="GECKO-A")
plt.plot(out_preds_df.loc[:574, col], color="green", label="Dense ANN Emulator")
plt.title("Aerosol [ug_m3] Bin08", fontsize=18)
plt.ylabel("Aerosol Concentration", fontsize=14)
plt.xlabel("Time Step", fontsize=14)
plt.legend(fontsize=14)
plt.savefig("plot3_Bin08_trial_%s.png" % trial, dpi=200, bbox_inches="tight")

#Aerosol [ug_m3] Bin07
col1 = output_data.columns[output_data.columns.str.contains("Aerosol")][6]
plt.figure(figsize=(5, 5))
plt.plot(output_data.loc[:574, col1], color='blue', label="GECKO-A")
plt.plot(out_preds_df.loc[:574, col1], color="orange", label="Dense ANN Emulator")
plt.title("Aerosol [ug_m3] Bin07", fontsize=18)
plt.ylabel("Aerosol [ug_m3] Bin07", fontsize=14)
plt.xlabel("Time Step", fontsize=14)
plt.legend(fontsize=14)
plt.savefig("plot3_Bin07_trial_%s.png" % trial, dpi=200, bbox_inches="tight")

#Aerosol [ug_m3] Bin06
col2 = output_data.columns[output_data.columns.str.contains("Aerosol")][5]
plt.figure(figsize=(5, 5))
plt.plot(output_data.loc[:574, col2], color='blue', label="GECKO-A")
plt.plot(out_preds_df.loc[:574, col2], color="purple", label="Dense ANN Emulator")
plt.title("Aerosol [ug_m3] Bin06", fontsize=18)
plt.ylabel("Aerosol Concentration", fontsize=14)
plt.xlabel("Time Step", fontsize=14)
plt.legend(fontsize=14)
plt.savefig("plot3_Bin06_trial_%s.png" % trial, dpi=200, bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-614fafe58b56> in <module>
#       1 #Aerosol [ug_m3] Bin08
# ----> 2 col = output_data.columns[output_data.columns.str.contains("Aerosol")][7]
#       3 plt.figure(figsize=(5, 5))
#       4 plt.plot(output_data.loc[:574, col], color='blue', label="GECKO-A")
#       5 plt.plot(out_preds_df.loc[:574, col], color="green", label="Dense ANN Emulator")
#
# NameError: name 'output_data' is not defined

# %%
output_data.columns[output_data.columns.str.contains("Aerosol")]
# Out:
# Index(['Aerosol [ug_m3] Bin01: lg(C*) = -5.5',
#        'Aerosol [ug_m3] Bin02: lg(C*) = -4.5',
#        'Aerosol [ug_m3] Bin03: lg(C*) = -3.5',
#        'Aerosol [ug_m3] Bin04: lg(C*) = -2.5',
#        'Aerosol [ug_m3] Bin05: lg(C*) = -1.5',
#        'Aerosol [ug_m3] Bin06: lg(C*) = -0.5',
#        'Aerosol [ug_m3] Bin07: lg(C*) =  0.5',
#        'Aerosol [ug_m3] Bin08: lg(C*) =  1.5',
#        'Aerosol [ug_m3] Bin09: lg(C*) =  2.5',
#        'Aerosol [ug_m3] Bin10: lg(C*) =  3.5',
#        'Aerosol [ug_m3] Bin11: lg(C*) =  4.5',
#        'Aerosol [ug_m3] Bin12: lg(C*) =  5.5',
#        'Aerosol [ug_m3] Bin13: lg(C*) =  6.5',
#        'Aerosol [ug_m3] Bin14: lg(C*) = -6.5'],
#       dtype='object')

# %%
(output_data.loc[:575, output_data.columns.str.contains("Gas")] - out_preds.loc[:575, output_data.columns.str.contains("Gas")]).values.max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-f06749f05806> in <module>
# ----> 1 (output_data.loc[:575, output_data.columns.str.contains("Gas")] - out_preds.loc[:575, output_data.columns.str.contains("Gas")]).values.max()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'loc'

# %%
for col in exp_data_merged.columns:
    print(repr(col))
# Out:
# 'Time [s]'
# 'Precursor [ug/m3]'
# 'Gas [ug/m3] Bin01: lg(C*) = -5.5'
# 'Gas [ug/m3] Bin02: lg(C*) = -4.5'
# 'Gas [ug/m3] Bin03: lg(C*) = -3.5'
# 'Gas [ug/m3] Bin04: lg(C*) = -2.5'
# 'Gas [ug/m3] Bin05: lg(C*) = -1.5'
# 'Gas [ug/m3] Bin06: lg(C*) = -0.5'
# 'Gas [ug/m3] Bin07: lg(C*) =  0.5'
# 'Gas [ug/m3] Bin08: lg(C*) =  1.5'
# 'Gas [ug/m3] Bin09: lg(C*) =  2.5'
# 'Gas [ug/m3] Bin10: lg(C*) =  3.5'
# 'Gas [ug/m3] Bin11: lg(C*) =  4.5'
# 'Gas [ug/m3] Bin12: lg(C*) =  5.5'
# 'Gas [ug/m3] Bin13: lg(C*) =  6.5'
# 'Gas [ug/m3] Bin14: lg(C*) = -6.5'
# 'Aerosol [ug_m3] Bin01: lg(C*) = -5.5'
# 'Aerosol [ug_m3] Bin02: lg(C*) = -4.5'
# 'Aerosol [ug_m3] Bin03: lg(C*) = -3.5'
# 'Aerosol [ug_m3] Bin04: lg(C*) = -2.5'
# 'Aerosol [ug_m3] Bin05: lg(C*) = -1.5'
# 'Aerosol [ug_m3] Bin06: lg(C*) = -0.5'
# 'Aerosol [ug_m3] Bin07: lg(C*) =  0.5'
# 'Aerosol [ug_m3] Bin08: lg(C*) =  1.5'
# 'Aerosol [ug_m3] Bin09: lg(C*) =  2.5'
# 'Aerosol [ug_m3] Bin10: lg(C*) =  3.5'
# 'Aerosol [ug_m3] Bin11: lg(C*) =  4.5'
# 'Aerosol [ug_m3] Bin12: lg(C*) =  5.5'
# 'Aerosol [ug_m3] Bin13: lg(C*) =  6.5'
# 'Aerosol [ug_m3] Bin14: lg(C*) = -6.5'
# 'Kh [M/atm] Bin01: lg(C*) = -5.5'
# 'Kh [M/atm] Bin02: lg(C*) = -4.5'
# 'Kh [M/atm] Bin03: lg(C*) = -3.5'
# 'Kh [M/atm] Bin04: lg(C*) = -2.5'
# 'Kh [M/atm] Bin05: lg(C*) = -1.5'
# 'Kh [M/atm] Bin06: lg(C*) = -0.5'
# 'Kh [M/atm] Bin07: lg(C*) =  0.5'
# 'Kh [M/atm] Bin08: lg(C*) =  1.5'
# 'Kh [M/atm] Bin09: lg(C*) =  2.5'
# 'Kh [M/atm] Bin10: lg(C*) =  3.5'
# 'Kh [M/atm] Bin11: lg(C*) =  4.5'
# 'Kh [M/atm] Bin12: lg(C*) =  5.5'
# 'Kh [M/atm] Bin13: lg(C*) =  6.5'
# 'Kh [M/atm] Bin14: lg(C*) = -6.5'
# 'MW [g/mol] Bin01: lg(C*) = -5.5'
# 'MW [g/mol] Bin02: lg(C*) = -4.5'
# 'MW [g/mol] Bin03: lg(C*) = -3.5'
# 'MW [g/mol] Bin04: lg(C*) = -2.5'
# 'MW [g/mol] Bin05: lg(C*) = -1.5'
# 'MW [g/mol] Bin06: lg(C*) = -0.5'
# 'MW [g/mol] Bin07: lg(C*) =  0.5'
# 'MW [g/mol] Bin08: lg(C*) =  1.5'
# 'MW [g/mol] Bin09: lg(C*) =  2.5'
# 'MW [g/mol] Bin10: lg(C*) =  3.5'
# 'MW [g/mol] Bin11: lg(C*) =  4.5'
# 'MW [g/mol] Bin12: lg(C*) =  5.5'
# 'MW [g/mol] Bin13: lg(C*) =  6.5'
# 'MW [g/mol] Bin14: lg(C*) = -6.5'
# 'dH [J/mol] Bin01: lg(C*) = -5.5'
# 'dH [J/mol] Bin02: lg(C*) = -4.5'
# 'dH [J/mol] Bin03: lg(C*) = -3.5'
# 'dH [J/mol] Bin04: lg(C*) = -2.5'
# 'dH [J/mol] Bin05: lg(C*) = -1.5'
# 'dH [J/mol] Bin06: lg(C*) = -0.5'
# 'dH [J/mol] Bin07: lg(C*) =  0.5'
# 'dH [J/mol] Bin08: lg(C*) =  1.5'
# 'dH [J/mol] Bin09: lg(C*) =  2.5'
# 'dH [J/mol] Bin10: lg(C*) =  3.5'
# 'dH [J/mol] Bin11: lg(C*) =  4.5'
# 'dH [J/mol] Bin12: lg(C*) =  5.5'
# 'dH [J/mol] Bin13: lg(C*) =  6.5'
# 'dH [J/mol] Bin14: lg(C*) = -6.5'
# 'kOH [cm3/molec/s] Bin01: lg(C*) = -5.5'
# 'kOH [cm3/molec/s] Bin02: lg(C*) = -4.5'
# 'kOH [cm3/molec/s] Bin03: lg(C*) = -3.5'
# 'kOH [cm3/molec/s] Bin04: lg(C*) = -2.5'
# 'kOH [cm3/molec/s] Bin05: lg(C*) = -1.5'
# 'kOH [cm3/molec/s] Bin06: lg(C*) = -0.5'
# 'kOH [cm3/molec/s] Bin07: lg(C*) =  0.5'
# 'kOH [cm3/molec/s] Bin08: lg(C*) =  1.5'
# 'kOH [cm3/molec/s] Bin09: lg(C*) =  2.5'
# 'kOH [cm3/molec/s] Bin10: lg(C*) =  3.5'
# 'kOH [cm3/molec/s] Bin11: lg(C*) =  4.5'
# 'kOH [cm3/molec/s] Bin12: lg(C*) =  5.5'
# 'kOH [cm3/molec/s] Bin13: lg(C*) =  6.5'
# 'kOH [cm3/molec/s] Bin14: lg(C*) = -6.5'
# 'O/C Bin01: lg(C*) = -5.5'
# 'O/C Bin02: lg(C*) = -4.5'
# 'O/C Bin03: lg(C*) = -3.5'
# 'O/C Bin04: lg(C*) = -2.5'
# 'O/C Bin05: lg(C*) = -1.5'
# 'O/C Bin06: lg(C*) = -0.5'
# 'O/C Bin07: lg(C*) =  0.5'
# 'O/C Bin08: lg(C*) =  1.5'
# 'O/C Bin09: lg(C*) =  2.5'
# 'O/C Bin10: lg(C*) =  3.5'
# 'O/C Bin11: lg(C*) =  4.5'
# 'O/C Bin12: lg(C*) =  5.5'
# 'O/C Bin13: lg(C*) =  6.5'
# 'O/C Bin14: lg(C*) = -6.5'
# 'H/C Bin01: lg(C*) = -5.5'
# 'H/C Bin02: lg(C*) = -4.5'
# 'H/C Bin03: lg(C*) = -3.5'
# 'H/C Bin04: lg(C*) = -2.5'
# 'H/C Bin05: lg(C*) = -1.5'
# 'H/C Bin06: lg(C*) = -0.5'
# 'H/C Bin07: lg(C*) =  0.5'
# 'H/C Bin08: lg(C*) =  1.5'
# 'H/C Bin09: lg(C*) =  2.5'
# 'H/C Bin10: lg(C*) =  3.5'
# 'H/C Bin11: lg(C*) =  4.5'
# 'H/C Bin12: lg(C*) =  5.5'
# 'H/C Bin13: lg(C*) =  6.5'
# 'H/C Bin14: lg(C*) = -6.5'
# 'N/C Bin01: lg(C*) = -5.5'
# 'N/C Bin02: lg(C*) = -4.5'
# 'N/C Bin03: lg(C*) = -3.5'
# 'N/C Bin04: lg(C*) = -2.5'
# 'N/C Bin05: lg(C*) = -1.5'
# 'N/C Bin06: lg(C*) = -0.5'
# 'N/C Bin07: lg(C*) =  0.5'
# 'N/C Bin08: lg(C*) =  1.5'
# 'N/C Bin09: lg(C*) =  2.5'
# 'N/C Bin10: lg(C*) =  3.5'
# 'N/C Bin11: lg(C*) =  4.5'
# 'N/C Bin12: lg(C*) =  5.5'
# 'N/C Bin13: lg(C*) =  6.5'
# 'N/C Bin14: lg(C*) = -6.5'
# 'id'
# 'temperature (K)'
# 'solar zenith angle (degree)'
# 'pre-existing aerosols (ug/m3)'
# 'o3 (ppb)'
# 'nox (ppb)'
# 'oh (10^6 molec/cm3)'

# %% [markdown]
# # Old exploratory processing code

# %%
data = pd.read_csv("/glade/scratch/siyuan/POSTPROCESSING/ML2019_toluene_kOH/Batch1_toluene/ML2019_toluene_kOH_ML2019_Exp0.csv")

# %%
exp_data_path = "/glade/scratch/siyuan/POSTPROCESSING/ML2019_toluene/ML2019_toluene_postproc/"
exp_data_files = sorted(glob(join(exp_data_path, "ML2019*.csv")))

# %%
file_template = "ML2019_toluene_ML2019_{exp}.csv"
exp_data = []
for exp in master_list["id"]:
    filename = join(exp_data_path, f"ML2019_toluene_ML2019_{exp}.csv")
    exp_data.append(pd.read_csv(filename))
    exp_data[-1].insert(0, "id", exp)

# %%
all_exp_data = pd.concat(exp_data, ignore_index=True)

# %%
all_exp_data.merge(master_list, on="id")
# Out:
#                id   Gas Phase [ug m-3]   Aerosol Phase [ug m-3]  \
# 0            Exp0             0.000000             0.000000e+00
# 1            Exp0             0.000000             0.000000e+00
# 2            Exp0             0.000000             0.000000e+00
# 3            Exp0             0.000000             0.000000e+00
# 4            Exp0             0.000000             0.000000e+00
# ...           ...                  ...                      ...
# 13547515  Exp1679             0.000037             5.037846e-09
# 13547516  Exp1679             0.007719             1.846604e-07
# 13547517  Exp1679             0.000253             1.129703e-09
# 13547518  Exp1679             0.000652             1.658724e-10
# 13547519  Exp1679             0.001670             5.746933e-11
#
#            Precursor [ug m-3]   Pvap bin lower limit [log10(Cstar)]  \
# 0                    0.000000                                 -16.0
# 1                    0.000000                                  -6.0
# 2                    0.000000                                  -5.0
# 3                    0.000000                                  -4.0
# 4                    0.000000                                  -3.0
# ...                       ...                                   ...
# 13547515             0.000000                                   2.0
# 13547516             0.000000                                   3.0
# 13547517             0.000000                                   4.0
# 13547518             0.000000                                   5.0
# 13547519             0.000002                                   6.0
#
#            Pvap bin upper limit [log10(Cstar)]   Time [s]    Kh [M/atm]  \
# 0                                         -6.0        1.0  0.000000e+00
# 1                                         -5.0        1.0  0.000000e+00
# 2                                         -4.0        1.0  0.000000e+00
# 3                                         -3.0        1.0  0.000000e+00
# 4                                         -2.0        1.0  0.000000e+00
# ...                                        ...        ...           ...
# 13547515                                   3.0   172800.0  5.974230e+11
# 13547516                                   4.0   172800.0  2.099617e+10
# 13547517                                   5.0   172800.0  1.920989e+10
# 13547518                                   6.0   172800.0  4.678444e+07
# 13547519                                  16.0   172800.0  9.991504e+07
#
#            MW [g/mol]   Yield (SOA)  ...   Atomic O/C ratio  \
# 0            0.000000           0.0  ...           0.000000
# 1            0.000000           0.0  ...           0.000000
# 2            0.000000           0.0  ...           0.000000
# 3            0.000000           0.0  ...           0.000000
# 4            0.000000           0.0  ...           0.000000
# ...               ...           ...  ...                ...
# 13547515   190.878196           0.0  ...           1.398678
# 13547516   190.256154           0.0  ...           0.776976
# 13547517   170.001702           0.0  ...           1.410147
# 13547518   124.006908           0.0  ...           0.768145
# 13547519   137.757838           0.0  ...           1.075160
#
#            Atomic H/C ratio   Atomic N/C ratio  \
# 0                  0.000000           0.000000
# 1                  0.000000           0.000000
# 2                  0.000000           0.000000
# 3                  0.000000           0.000000
# 4                  0.000000           0.000000
# ...                     ...                ...
# 13547515           1.001275           0.198914
# 13547516           0.757387           0.310681
# 13547517           0.882486           0.267623
# 13547518           0.866488           0.038317
# 13547519           1.014858           0.231805
#
#            Vaporization Enthalpy [J/mol]                                                                                                   \
# 0                                                  0.000000
# 1                                                  0.000000
# 2                                                  0.000000
# 3                                                  0.000000
# 4                                                  0.000000
# ...                                                     ...
# 13547515                                      111930.948306
# 13547516                                       98830.435047
# 13547517                                       94664.634832
# 13547518                                       78111.230330
# 13547519                                       60424.779544
#
#            temperature (K)   solar zenith angle (degree)  \
# 0                      300                             0
# 1                      300                             0
# 2                      300                             0
# 3                      300                             0
# 4                      300                             0
# ...                    ...                           ...
# 13547515               300                            90
# 13547516               300                            90
# 13547517               300                            90
# 13547518               300                            90
# 13547519               300                            90
#
#            pre-existing aerosols (ug/m3)   o3 (ppb)   nox (ppb)  \
# 0                                  10.00         10        0.01
# 1                                  10.00         10        0.01
# 2                                  10.00         10        0.01
# 3                                  10.00         10        0.01
# 4                                  10.00         10        0.01
# ...                                  ...        ...         ...
# 13547515                            0.01         90       10.00
# 13547516                            0.01         90       10.00
# 13547517                            0.01         90       10.00
# 13547518                            0.01         90       10.00
# 13547519                            0.01         90       10.00
#
#            oh (10^6 molec/cm3)
# 0                            5
# 1                            5
# 2                            5
# 3                            5
# 4                            5
# ...                        ...
# 13547515                    10
# 13547516                    10
# 13547517                    10
# 13547518                    10
# 13547519                    10
#
# [13547520 rows x 21 columns]

# %%
exp_0.columns.str.lstrip()
# Out:
# Index(['Gas Phase [ug m-3]', 'Aerosol Phase [ug m-3]', 'Precursor [ug m-3]',
#        'Pvap bin lower limit [log10(Cstar)]',
#        'Pvap bin upper limit [log10(Cstar)]', 'Time [s]', 'Kh [M/atm]',
#        'MW [g/mol]', 'Yield (SOA)', 'Yield (total)', 'Atomic O/C ratio',
#        'Atomic H/C ratio', 'Atomic N/C ratio',
#        'Vaporization Enthalpy [J/mol]                                                                                                 '],
#       dtype='object')

# %%
! du -sh /glade/scratch/siyuan/POSTPROCESSING/ML2019_toluene/ML2019_toluene_postproc/
# Out:
# 5.2G	/glade/scratch/siyuan/POSTPROCESSING/ML2019_toluene/ML2019_toluene_postproc/

# %%
exp_0 = pd.read_csv(exp_data_files[42])

# %%
times = np.sort(exp_0[" Time [s]"].unique())

# %%
bin_aerosol_vectors = exp_0[" Aerosol Phase [ug m-3]"].values.reshape(times.size, 14)

# %%
bin_gas_vectors = exp_0[" Gas Phase [ug m-3]"].values.reshape(times.size, 14)

# %%
bin_values = exp_0[' Pvap bin lower limit [log10(Cstar)]'][exp_0[" Time [s]"] == times[0]].values
bin_values = np.append(bin_values, [16])

# %%
plt.figure(figsize=(12, 10))
plt.subplot(1, 2, 1)
plt.pcolormesh(bin_values, times[10:], bin_aerosol_vectors[10:], cmap=plt.get_cmap("YlOrRd", 20))
plt.title("Aerosol Bin Concentrations")
plt.colorbar()
plt.subplot(1, 2, 2)
plt.pcolormesh(bin_values, times[10:], bin_gas_vectors[10:], cmap=plt.get_cmap("YlOrRd", 20))
plt.title("Gas Bin Concentrations")
plt.colorbar()

# %%
plt.figure(figsize=(12, 10))
plt.subplot(1, 2, 1)
plt.pcolormesh(bin_values, times[10:], bin_aerosol_vectors[10:], cmap=plt.get_cmap("YlOrRd", 20), norm=LogNorm(1e-15, 0.01))
plt.title("Aerosol Bin Concentrations")
plt.colorbar()
plt.subplot(1, 2, 2)
plt.pcolormesh(bin_values, times[10:], bin_gas_vectors[10:], cmap=plt.get_cmap("YlOrRd", 20), norm=LogNorm(1e-15, 0.01))
plt.title("Gas Bin Concentrations")
plt.colorbar()

# %%
plt.plot(np.log10(bin_aerosol_vectors[10:, :]))
# Out:
# [<matplotlib.lines.Line2D at 0x2b3b13fca5f8>,
#  <matplotlib.lines.Line2D at 0x2b3b13fca748>,
#  <matplotlib.lines.Line2D at 0x2b3b13fca898>,
#  <matplotlib.lines.Line2D at 0x2b3b13fca9e8>,
#  <matplotlib.lines.Line2D at 0x2b3b13fcab38>,
#  <matplotlib.lines.Line2D at 0x2b3b13fcac88>,
#  <matplotlib.lines.Line2D at 0x2b3b13fcadd8>,
#  <matplotlib.lines.Line2D at 0x2b3b13fcaf28>,
#  <matplotlib.lines.Line2D at 0x2b3b13fd10b8>,
#  <matplotlib.lines.Line2D at 0x2b3b13fd1208>,
#  <matplotlib.lines.Line2D at 0x2b3b13f9c208>,
#  <matplotlib.lines.Line2D at 0x2b3b13fd1470>,
#  <matplotlib.lines.Line2D at 0x2b3b13fd15c0>,
#  <matplotlib.lines.Line2D at 0x2b3b13fd1710>]

# %%
bin_aerosol_vectors.shape
# Out:
# (576, 14)

# %%
plt.plot(bin_aerosol_vectors)
# Out:
# [<matplotlib.lines.Line2D at 0x2b3b138ac898>,
#  <matplotlib.lines.Line2D at 0x2b3b138ac9e8>,
#  <matplotlib.lines.Line2D at 0x2b3b138acb38>,
#  <matplotlib.lines.Line2D at 0x2b3b138acc88>,
#  <matplotlib.lines.Line2D at 0x2b3b138acdd8>,
#  <matplotlib.lines.Line2D at 0x2b3b138acf28>,
#  <matplotlib.lines.Line2D at 0x2b3b138b60b8>,
#  <matplotlib.lines.Line2D at 0x2b3b138b6208>,
#  <matplotlib.lines.Line2D at 0x2b3b138b6358>,
#  <matplotlib.lines.Line2D at 0x2b3b138b64a8>,
#  <matplotlib.lines.Line2D at 0x2b3b13885390>,
#  <matplotlib.lines.Line2D at 0x2b3b138b6710>,
#  <matplotlib.lines.Line2D at 0x2b3b138b6860>,
#  <matplotlib.lines.Line2D at 0x2b3b138b69b0>]
