# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
f = pd.read_csv("results/9_29/row1/training_log.csv")

# %%
f["epoch"] = f["epoch"] + 1.0

# %%
plt.plot(f.index, f["train_loss"], color = 'k')
plt.plot(f.index, f["valid_loss"], color = 'r')

#plt.xscale('log')
plt.yscale('log')

plt.xlim([0,1000])
plt.ylim([0,10])

_ = plt.xlabel("Epochs")
_ = plt.ylabel("Loss")

plt.legend(["Train", "Validation"])
# Out:
# /glade/work/schreck/py37/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
